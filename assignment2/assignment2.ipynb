# %% [markdown]
# # Assignment 2
#
# ## 1st step
# The window to consider is from 01-01-2013-00:00 to 31-12-2013-23:59.
#
# First thing to do is to get the list of commits in that timespan, including for each of them the information about the author, changed files, and timestamp. We can then create the following structure, in which the "primary key" is the (commit, filepath) pair:
#
#     struct = {
#         (‘commit_hash_1’, 'path/to/a.java’): {‘timestamp’: ‘timestamp_1’,
#                                               'author': 'email@example.com'
#                                               },
#         (‘commit_hash_2’, ‘path/to/b.java’): {‘timestamp’: ‘timestamp_2’,
#                                               'author': 'email@example.com'
#                                               },
#         (‘commit_hash_2’, ‘path/to/c.java’): {‘timestamp’: ‘timestamp_2’,
#                                               'author': 'email@example.com'
#                                               },
#         (‘commit_hash_3’, ‘path/to/d.java’): {‘timestamp’: ‘timestamp_3’,
#                                               'author': 'email@example.com'
#                                               },
#         (‘commit_hash_3’, 'path/to/e.java’): {‘timestamp’: ‘timestamp_3’,
#                                               'author': 'email@example.com'
#                                               },
#     }

# %% [markdown]
# Let's first import the Python modules we need

# %%
import sh
import re
import sys
from collections import Counter

# %% [markdown]
# And position ourselves in the right directory

# %%
git = sh.git.bake(_cwd='lucene-solr')

# %% [markdown]
# We can then proceed with the first step

# %%
# for testing purposes we restrict the timespan to
# speed up development
log_output = str(git('--no-pager', 'log', '--name-only', after='2015-11-01 00:00',
                 before='2016-01-01 00:00', pretty="format:(%H,%at,%ae)"))

splitted_output = (s.split('\n') for s in log_output.split('\n\n'))

struct = {}

for commit_group in splitted_output:
    i = 0

    # filter out empty commits
    while commit_group[i+1][0] == '(' and commit_group[i+1][-1] == ')':
        i += 1

    commit_info = commit_group[i][1:-1]

    commit_hash, timestamp, author_email = commit_info.split(',')

    changed_files = commit_group[i+1:]

    # we are interested only in Java files inside the core
    core_regex = r'^lucene\/core\/src\/java\/org\/apache\/lucene.*?\.java$'

    for file_path in changed_files:
        if file_path and re.match(core_regex, file_path):
            struct[(commit_hash, file_path)] = {
                'timestamp': timestamp,
                'author_email': author_email
            }
            
struct
# Out:
# {('0bc10ecb72c68b27230659f728db0b8e6996ca40',
#   'lucene/core/src/java/org/apache/lucene/util/RamUsageEstimator.java'): {'author_email': 'rmuir@apache.org',
#   'timestamp': '1449425049'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/ConjunctionDISI.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/DisjunctionScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/ExactPhraseScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/MultiPhraseQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/PhraseQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/RandomAccessWeight.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/ReqExclScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/SloppyPhraseScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/TwoPhaseIterator.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ConjunctionSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/FilterSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/NearSpansUnordered.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ScoringWrapperSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanNearQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanOrQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanTermQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/Spans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/TermSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('132986048f37d504f9c34f9ba2acb51b702a557f',
#   'lucene/core/src/java/org/apache/lucene/util/Version.java'): {'author_email': 'anshum@apache.org',
#   'timestamp': '1450882752'},
#  ('1967050202dc9bed410c74ac650b04261f41dfc6',
#   'lucene/core/src/java/org/apache/lucene/search/DisiWrapper.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449851410'},
#  ('1967050202dc9bed410c74ac650b04261f41dfc6',
#   'lucene/core/src/java/org/apache/lucene/search/DisjunctionScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1
java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1446373190'},
#  ('d3869edb96d18c5393047ee10a7cf37e4988c530',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1446373190'},
#  ('d5ebe9cd85e89401c8cbc920b4527f1141142479',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene60/Lucene60DimensionalReader.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1450448699'},
#  ('d5ebe9cd85e89401c8cbc920b4527f1141142479',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene60/Lucene60DimensionalWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1450448699'},
#  ('d5ebe9cd85e89401c8cbc920b4527f1141142479',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDReader.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1450448699'},
#  ('d5ebe9cd85e89401c8cbc920b4527f1141142479',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1450448699'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/index/BufferedUpdatesStream.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/BooleanTopLevelScorers.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/BulkScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/CachingCollector.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/ConjunctionDISI.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/ConjunctionScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/ConstantScoreScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/ConstantScoreWeight.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/DisiPriorityQueue.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/DisiWrapper.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/DisjunctionDISIApproximation.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/DisjunctionMaxScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/DisjunctionScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/DisjunctionSumScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/ExactPhraseScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/FakeScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/FilterScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/MinShouldMatchSumScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/MultiPhraseQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/PhraseQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/QueryRescorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/ReqExclScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/ReqOptSumScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/Scorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/SloppyPhraseScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/SynonymQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/TermQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/TermScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/TwoPhaseIterator.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/Weight.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/package-info.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ConjunctionSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ContainSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/FilterSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/NearSpansOrdered.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/NearSpansUnordered.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ScoringWrapperSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanBoostQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanContainingQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanNearQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanNotQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanOrQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanPositionCheckQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanTermQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanWeight.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanWithinQuery.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/Spans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/TermSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('e7735086485d196b7813810fe355d82a20147283',
#   'lucene/core/src/java/org/apache/lucene/search/BooleanScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1451569279'},
#  ('e7735086485d196b7813810fe355d82a20147283',
#   'lucene/core/src/java/org/apache/lucene/search/BooleanWeight.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1451569279'},
#  ('e7735086485d196b7813810fe355d82a20147283',
#   'lucene/core/src/java/org/apache/lucene/search/ReqExclBulkScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1451569279'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/codecs/DimensionalWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene60/Lucene60DimensionalWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/document/DimensionalField.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/CheckIndex.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/CodecReader.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/DefaultIndexingChain.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/DimensionalValues.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/ParallelLeafReader.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/search/DimensionalRangeQuery.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/util/StringHelper.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDReader.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDUtil.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f25c8907098135fd61a6f068229367a8476f0550',
#   'lucene/core/src/java/org/apache/lucene/util/StringHelper.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447172780'},
#  ('f25c8907098135fd61a6f068229367a8476f0550',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDReader.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447172780'},
#  ('f25c8907098135fd61a6f068229367a8476f0550',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447172780'},
#  ('f9b446d66f1ae4b00c38f558e31757216e810fae',
#   'lucene/core/src/java/org/apache/lucene/search/LRUQueryCache.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449231766'}}

# %% [markdown]
# To get the line contributors metrics set we need to use the “git blame” command, which returns all the lines of the file as well as the author of each line.
#
# For each (commit_hash, filepath) pair we “git blame” (commit_hash^1, filepath) since we are interested in the state of the file before the changes made by the commit. If the file didn’t exist before the commit we are analyzing (i.e., it was created by that commit) we leave the metrics columns blank.
#
# As an intermediary step,, for each (commit_hash, filepath) we compute the following
#
#     struct_line_contributors = {
#     	‘author_1’: lines_contributed_by_author_1,
# 	    ‘author_2’: lines_contributed_by_author_2,
# 	    ‘author_3’: lines_contributed_by_author_3,
#     	...
#     }
#
# We then are able to compute the following metrics:
#
# - `line_contributors_total`: number of developers who contributed to at least one line in the committed file (= number of keys in the dictionary)
# - `line_contributors_minor`: number of developers who contributed to <= 5% of the lines in the committed file (lines_contributed_by_author/total_lines < 0.05)
# - `line_contributors_major`: number of developers who contributed to > 5% of the lines in the committed file, comprising the author (lines_contributed_by_author/total_lines > 0.05)
# - `line_contributors_ownership`: ratio of lines by the developers with the highest number of lines (lines_contributed_by_highest_contributors/total_lines)
# - `line_contributors_author`: ratio of lines by the developer who is author of the current commit (lines_contributed_author/total_lines)
# - `line_contributors_author_owner`: true if the developer who is author of the current commit is the one with the highest ratio of contributed lines

# %%
for ((commit_hash, file_path), info) in struct.items():
    try:
        blame_out = str(
            git('--no-pager', 'blame', file_path, commit_hash + '^1',
                '--line-porcelain').stdout,
            encoding=sys.stdout.encoding)
    except sh.ErrorReturnCode_128:
        # the file was not found at that specific commit,
        # meaning that it still didn't exist
        continue

    authors = re.findall(r'^author-mail <(.*)>', blame_out, flags=re.M)
    authors_counter = Counter(authors)

    line_contributors_total = len(authors_counter)
    total_lines = sum(authors_counter.values())

    line_contributors_minor, line_contributors_major = 0, 0
    for author, n_lines in authors_counter.items():
        if n_lines/total_lines < 0.05:
            line_contributors_minor += 1
        else:
            line_contributors_major += 1

    commit_author = info['author_email']
    if commit_author in authors_counter:
        line_contributors_author = authors_counter[commit_author]/total_lines
    else:
        line_contributors_author = 0

    author_max_lines = max(authors_counter.keys(),
                           key=(lambda k: authors_counter[k]))

    line_contributors_ownership = \
        authors_counter[author_max_lines] / total_lines

    line_contributors_author_owner = \
        True if author_max_lines == commit_author else False

    info.update({
        'line_contributors_total': line_contributors_total,
        'line_contributors_minor': line_contributors_minor,
        'line_contributors_major': line_contributors_major,
        'line_contributors_author': line_contributors_author,
        'line_contributors_ownership': line_contributors_ownership,
        'line_contributors_author_owner': line_contributors_author_owner})
    
struct
# Out:
# {('0bc10ecb72c68b27230659f728db0b8e6996ca40',
#   'lucene/core/src/java/org/apache/lucene/util/RamUsageEstimator.java'): {'author_email': 'rmuir@apache.org',
#   'line_contributors_author': 0.010752688172043012,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.7258064516129032,
#   'line_contributors_total': 4,
#   'timestamp': '1449425049'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/ConjunctionDISI.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.8264840182648402,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 3,
#   'line_contributors_ownership': 0.8264840182648402,
#   'line_contributors_total': 5,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/DisjunctionScorer.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.5617977528089888,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 3,
#   'line_contributors_ownership': 0.5617977528089888,
#   'line_contributors_total': 5,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/ExactPhraseScorer.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.4581005586592179,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 5,
#   'line_contributors_ownership': 0.4581005586592179,
#   'line_contributors_total': 9,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/MultiPhraseQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.0696798493408663,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 6,
#   'line_contributors_minor': 8,
#   'line_contributors_ownership': 0.3634651600753296,
#   'line_contributors_total': 14,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/PhraseQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.5056179775280899,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 7,
#   'line_contributors_minor': 13,
#   'line_contributors_ownership': 0.5056179775280899,
#   'line_contributors_total': 20,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/RandomAccessWeight.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 1.0,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 1.0,
#   'line_contributors_total': 1,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/ReqExclScorer.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.525974025974026,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 6,
#   'line_contributors_ownership': 0.525974025974026,
#   'line_contributors_total': 9,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/SloppyPhraseScorer.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.0632279534109817,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 4,
#   'line_contributors_ownership': 0.7254575707154742,
#   'line_contributors_total': 8,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/TwoPhaseIterator.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.7572815533980582,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 0.7572815533980582,
#   'line_contributors_total': 3,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ConjunctionSpans.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.9711538461538461,
#   'line_contributors_total': 2,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/FilterSpans.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.024390243902439025,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 3,
#   'line_contributors_ownership': 0.6146341463414634,
#   'line_contributors_total': 5,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/NearSpansUnordered.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.0364963503649635,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 3,
#   'line_contributors_ownership': 0.4343065693430657,
#   'line_contributors_total': 7,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ScoringWrapperSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanNearQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.061696658097686374,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 5,
#   'line_contributors_ownership': 0.6272493573264781,
#   'line_contributors_total': 8,
#   'timestamp': '1447445281'},
#  ('0ed54b3105c6f6462293b69792d3878d6f0a7bbc',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanOrQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.06376811594202898,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 5,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0

#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 1.0,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 1.0,
#   'line_contributors_total': 1,
#   'timestamp': '1450463132'},
#  ('553a0920c3b3295de46c918e4b89bbd7ea654e83',
#   'lucene/core/src/java/org/apache/lucene/codecs/CodecUtil.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 0.025806451612903226,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 4,
#   'line_contributors_ownership': 0.8344086021505376,
#   'line_contributors_total': 6,
#   'timestamp': '1446735383'},
#  ('562d97a69d915bcf537e307754f5574790758c2d',
#   'lucene/core/src/java/org/apache/lucene/index/CheckIndex.java'): {'author_email': 'gchanan@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 12,
#   'line_contributors_ownership': 0.5178786661309763,
#   'line_contributors_total': 14,
#   'timestamp': '1448923608'},
#  ('60bb927256534e446b4fb75f13c0b8972df4b5be',
#   'lucene/core/src/java/org/apache/lucene/search/MultiPhraseQuery.java'): {'author_email': 'dsmiley@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 6,
#   'line_contributors_minor': 8,
#   'line_contributors_ownership': 0.35567970204841715,
#   'line_contributors_total': 14,
#   'timestamp': '1448302628'},
#  ('60bb927256534e446b4fb75f13c0b8972df4b5be',
#   'lucene/core/src/java/org/apache/lucene/search/PhraseQuery.java'): {'author_email': 'dsmiley@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 7,
#   'line_contributors_minor': 13,
#   'line_contributors_ownership': 0.5467128027681661,
#   'line_contributors_total': 20,
#   'timestamp': '1448302628'},
#  ('69b467a24b8881dec45e6615912b191bb6d7760a',
#   'lucene/core/src/java/org/apache/lucene/index/IndexWriter.java'): {'author_email': 'rmuir@apache.org',
#   'line_contributors_author': 0.061436280614362807,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 17,
#   'line_contributors_ownership': 0.6664591116645912,
#   'line_contributors_total': 21,
#   'timestamp': '1446564542'},
#  ('6da5a2d14fa699877169098f5e7fe92a1916adf3',
#   'lucene/core/src/java/org/apache/lucene/index/IndexWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 0.6646644573322287,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 18,
#   'line_contributors_ownership': 0.6646644573322287,
#   'line_contributors_total': 22,
#   'timestamp': '1447342019'},
#  ('724e803e1956ce57c77d05f27be60d0fafdcb621',
#   'lucene/core/src/java/org/apache/lucene/search/TopDocs.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.11,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 8,
#   'line_contributors_ownership': 0.6633333333333333,
#   'line_contributors_total': 11,
#   'timestamp': '1446560300'},
#  ('7b32197915545526c3a692f9eba3952e9f2a50ba',
#   'lucene/core/src/java/org/apache/lucene/index/CheckIndex.java'): {'author_email': 'cpoerschke@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 12,
#   'line_contributors_ownership': 0.49627012171181784,
#   'line_contributors_total': 15,
#   'timestamp': '1449161553'},
#  ('7bea628bf3961a10581833935e4c1b61ad708c5c',
#   'lucene/core/src/java/org/apache/lucene/util/IOUtils.java'): {'author_email': 'uschindler@apache.org',
#   'line_contributors_author': 0.10260869565217391,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 4,
#   'line_contributors_ownership': 0.4260869565217391,
#   'line_contributors_total': 8,
#   'timestamp': '1448188436'},
#  ('7c917a5ed8404819fcc38257df949612c8dcf653',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene54/Lucene54DocValuesConsumer.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.23100303951367782,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 2,
#   'line_contributors_ownership': 0.7629179331306991,
#   'line_contributors_total': 4,
#   'timestamp': '1446815076'},
#  ('7c917a5ed8404819fcc38257df949612c8dcf653',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene54/Lucene54DocValuesFormat.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.15867158671586715,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 2,
#   'line_contributors_ownership': 0.8302583025830258,
#   'line_contributors_total': 4,
#   'timestamp': '1446815076'},
#  ('7c917a5ed8404819fcc38257df949612c8dcf653',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene54/Lucene54DocValuesProducer.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.2531152647975078,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 2,
#   'line_contributors_ownership': 0.7429906542056075,
#   'line_contributors_total': 4,
#   'timestamp': '1446815076'},
#  ('7da175b0b6b4185ee6b5df852e59b93d9a9a1c86',
#   'lucene/core/src/java/org/apache/lucene/analysis/LegacyNumericTokenStream.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1449868421'},
#  ('7da175b0b6b4185ee6b5df852e59b93d9a9a1c86',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene60/Lucene
},
#  ('a4b4c75dcfdce362eeca1117be88ca803282a820',
#   'lucene/core/src/java/org/apache/lucene/index/IndexWriter.java'): {'author_email': 'cpoerschke@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 17,
#   'line_contributors_ownership': 0.6641094754302301,
#   'line_contributors_total': 21,
#   'timestamp': '1447264320'},
#  ('a4b4c75dcfdce362eeca1117be88ca803282a820',
#   'lucene/core/src/java/org/apache/lucene/index/LogMergePolicy.java'): {'author_email': 'cpoerschke@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 4,
#   'line_contributors_ownership': 0.40793650793650793,
#   'line_contributors_total': 8,
#   'timestamp': '1447264320'},
#  ('a4b4c75dcfdce362eeca1117be88ca803282a820',
#   'lucene/core/src/java/org/apache/lucene/index/MultiFields.java'): {'author_email': 'cpoerschke@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 5,
#   'line_contributors_ownership': 0.503731343283582,
#   'line_contributors_total': 9,
#   'timestamp': '1447264320'},
#  ('a4b4c75dcfdce362eeca1117be88ca803282a820',
#   'lucene/core/src/java/org/apache/lucene/index/SegmentDocValuesProducer.java'): {'author_email': 'cpoerschke@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.9085714285714286,
#   'line_contributors_total': 3,
#   'timestamp': '1447264320'},
#  ('bfffa7e0df31ea04b80147271cb60b03527be69f',
#   'lucene/core/src/java/org/apache/lucene/util/Version.java'): {'author_email': 'upayavira@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 7,
#   'line_contributors_ownership': 0.37341772151898733,
#   'line_contributors_total': 11,
#   'timestamp': '1448462805'},
#  ('ccc60d6a110b0aad3252aab541221f91d2f5b249',
#   'lucene/core/src/java/org/apache/lucene/util/AttributeSource.java'): {'author_email': 'uschindler@apache.org',
#   'line_contributors_author': 0.46916299559471364,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 5,
#   'line_contributors_ownership': 0.46916299559471364,
#   'line_contributors_total': 7,
#   'timestamp': '1446890794'},
#  ('d3869edb96d18c5393047ee10a7cf37e4988c530',
#   'lucene/core/src/java/org/apache/lucene/codecs/Codec.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 0.06060606060606061,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 3,
#   'line_contributors_ownership': 0.48484848484848486,
#   'line_contributors_total': 6,
#   'timestamp': '1446373190'},
#  ('d3869edb96d18c5393047ee10a7cf37e4988c530',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene60/Lucene60Codec.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1446373190'},
#  ('d3869edb96d18c5393047ee10a7cf37e4988c530',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene60/Lucene60DimensionalFormat.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1446373190'},
#  ('d3869edb96d18c5393047ee10a7cf37e4988c530',
# ...
#   'line_contributors_major': 8,
#   'line_contributors_minor': 5,
#   'line_contributors_ownership': 0.3080357142857143,
#   'line_contributors_total': 13,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/TermScorer.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 7,
#   'line_contributors_minor': 4,
#   'line_contributors_ownership': 0.20833333333333334,
#   'line_contributors_total': 11,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/TwoPhaseIterator.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.7837837837837838,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 0.7837837837837838,
#   'line_contributors_total': 3,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/Weight.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.3905579399141631,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 5,
#   'line_contributors_ownership': 0.3905579399141631,
#   'line_contributors_total': 8,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/package-info.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.02040816326530612,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 2,
#   'line_contributors_ownership': 0.974025974025974,
#   'line_contributors_total': 3,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ConjunctionSpans.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.1774193548387097,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.7983870967741935,
#   'line_contributors_total': 3,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ContainSpans.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.07936507936507936,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 0.8095238095238095,
#   'line_contributors_total': 3,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/FilterSpans.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.13043478260869565,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 2,
#   'line_contributors_ownership': 0.5478260869565217,
#   'line_contributors_total': 5,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/NearSpansOrdered.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.037267080745341616,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 3,
#   'line_contributors_ownership': 0.37888198757763975,
#   'line_contributors_total': 6,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/NearSpansUnordered.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.053763440860215055,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 5,
#   'line_contributors_minor': 2,
#   'line_contributors_ownership': 0.4265232974910394,
#   'line_contributors_total': 7,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/ScoringWrapperSpans.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanBoostQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 1.0,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 1.0,
#   'line_contributors_total': 1,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanContainingQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.03361344537815126,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.5798319327731093,
#   'line_contributors_total': 3,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanNearQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.07360406091370558,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 5,
#   'line_contributors_ownership': 0.6192893401015228,
#   'line_contributors_total': 8,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanNotQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.03056768558951965,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 3,
#   'line_contributors_ownership': 0.39737991266375544,
#   'line_contributors_total': 7,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanOrQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.15384615384615385,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 5,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.4854111405835544,
#   'line_contributors_total': 6,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanPositionCheckQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.10948905109489052,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 4,
#   'line_contributors_ownership': 0.4306569343065693,
#   'line_contributors_total': 8,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanTermQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.19337016574585636,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 4,
#   'line_contributors_ownership': 0.4198895027624309,
#   'line_contributors_total': 7,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanWeight.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.09090909090909091,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 7,
#   'line_contributors_ownership': 0.6121212121212121,
#   'line_contributors_total': 11,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/SpanWithinQuery.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.03305785123966942,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.5702479338842975,
#   'line_contributors_total': 3,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/Spans.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.10396039603960396,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 5,
#   'line_contributors_ownership': 0.5891089108910891,
#   'line_contributors_total': 9,
#   'timestamp': '1449755030'},
#  ('ddb3a97678fa112292c0f5aed271087a79281d12',
#   'lucene/core/src/java/org/apache/lucene/search/spans/TermSpans.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.11428571428571428,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.45,
#   'line_contributors_total': 5,
#   'timestamp': '1449755030'},
#  ('e7735086485d196b7813810fe355d82a20147283',
#   'lucene/core/src/java/org/apache/lucene/search/BooleanScorer.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.8702702702702703,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 3,
#   'line_contributors_ownership': 0.8702702702702703,
#   'line_contributors_total': 5,
#   'timestamp': '1451569279'},
#  ('e7735086485d196b7813810fe355d82a20147283',
#   'lucene/core/src/java/org/apache/lucene/search/BooleanWeight.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 0.3721973094170404,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.625560538116592,
#   'line_contributors_total': 3,
#   'timestamp': '1451569279'},
#  ('e7735086485d196b7813810fe355d82a20147283',
#   'lucene/core/src/java/org/apache/lucene/search/ReqExclBulkScorer.java'): {'author_email': 'jpountz@apache.org',
#   'timestamp': '1451569279'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/codecs/DimensionalWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/codecs/lucene60/Lucene60DimensionalWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/document/DimensionalField.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/CheckIndex.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 0.5178786661309763,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 12,
#   'line_contributors_ownership': 0.5178786661309763,
#   'line_contributors_total': 14,
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/CodecReader.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 0.018134715025906734,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.9818652849740933,
#   'line_contributors_total': 2,
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/DefaultIndexingChain.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 0.9272486772486772,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 2,
#   'line_contributors_minor': 1,
#   'line_contributors_ownership': 0.9272486772486772,
#   'line_contributors_total': 3,
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/DimensionalValues.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/index/ParallelLeafReader.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 0.14942528735632185,
#   'line_contributors_author_owner': False,
#   'line_contributors_major': 4,
#   'line_contributors_minor': 3,
#   'line_contributors_ownership': 0.5804597701149425,
#   'line_contributors_total': 7,
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/search/DimensionalRangeQuery.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/util/StringHelper.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 0.5065274151436031,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 6,
#   'line_contributors_ownership': 0.5065274151436031,
#   'line_contributors_total': 9,
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDReader.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 1.0,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 1.0,
#   'line_contributors_total': 1,
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDUtil.java'): {'author_email': 'mikemccand@apache.org',
#   'timestamp': '1447006699'},
#  ('f12cb52a3b8ca410efa2eace2354cf9d03191e0e',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 1.0,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 1.0,
#   'line_contributors_total': 1,
#   'timestamp': '1447006699'},
#  ('f25c8907098135fd61a6f068229367a8476f0550',
#   'lucene/core/src/java/org/apache/lucene/util/StringHelper.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 0.5239294710327456,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 3,
#   'line_contributors_minor': 6,
#   'line_contributors_ownership': 0.5239294710327456,
#   'line_contributors_total': 9,
#   'timestamp': '1447172780'},
#  ('f25c8907098135fd61a6f068229367a8476f0550',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDReader.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 1.0,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 1.0,
#   'line_contributors_total': 1,
#   'timestamp': '1447172780'},
#  ('f25c8907098135fd61a6f068229367a8476f0550',
#   'lucene/core/src/java/org/apache/lucene/util/bkd/BKDWriter.java'): {'author_email': 'mikemccand@apache.org',
#   'line_contributors_author': 1.0,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 1.0,
#   'line_contributors_total': 1,
#   'timestamp': '1447172780'},
#  ('f9b446d66f1ae4b00c38f558e31757216e810fae',
#   'lucene/core/src/java/org/apache/lucene/search/LRUQueryCache.java'): {'author_email': 'jpountz@apache.org',
#   'line_contributors_author': 1.0,
#   'line_contributors_author_owner': True,
#   'line_contributors_major': 1,
#   'line_contributors_minor': 0,
#   'line_contributors_ownership': 1.0,
#   'line_contributors_total': 1,
#   'timestamp': '1449231766'}}
